# %% [markdown]
# <a href="https://colab.research.google.com/github/padhma4782/AI-ML-Practice-sheets/blob/main/Guvi_DS_Session10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

# %%
conn = sqlite3.connect('test.db')

# %%
conn.execute(''' CREATE TABLE Employees (emp_id INT, emp_name VARCHAR, address VARCHAR, dept_id INT, dept_name VARCHAR, salary INT); ''')
conn.commit()

print("table created")
# Out:
# table created

# %%
cursor = conn.execute(""" SELECT * FROM Employees""")
for row in cursor:
  print(row)

# %%
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (101, 'P1', 'A1', 1, 'D1', 1000); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (102, 'P2', 'A2', 2, 'D2', 10000); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (103, 'P3', 'A3', 3, 'D3', 12000); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (104, 'P4', 'A4', 2, 'D2', 11000); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (105, 'P5', 'A5', 1, 'D1', 1200); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (106, 'P6', 'A6', 3, 'D3', 1300); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (107, 'P7', 'A7', 2, 'D2', 1400); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (108, 'P8', 'A8', 4, 'D4', 12100); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (109, 'P9', 'A9', 4, 'D4', 10030); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (110, 'P10', 'A10', 2, 'D2', 10200); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (111, 'P11', 'A11', 1, 'D1', 10200); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (112, 'P12', 'A12', 3, 'D3', 10040); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (113, 'P13', 'A13', 2, 'D2', 10200); """)

conn.commit()

# %%
#conn = sqlite3.connect('test.db')
cursor = conn.execute("select * from Employees;")
for row in cursor:
  print(row)
# Out:
# (101, 'P1', 'A1', 1, 'D1', 1000)
# (102, 'P2', 'A2', 2, 'D2', 10000)
# (103, 'P3', 'A3', 3, 'D3', 12000)
# (104, 'P4', 'A4', 2, 'D2', 11000)
# (105, 'P5', 'A5', 1, 'D1', 1200)
# (106, 'P6', 'A6', 3, 'D3', 1300)
# (107, 'P7', 'A7', 2, 'D2', 1400)
# (108, 'P8', 'A8', 4, 'D4', 12100)
# (109, 'P9', 'A9', 4, 'D4', 10030)
# (110, 'P10', 'A10', 2, 'D2', 10200)
# (111, 'P11', 'A11', 1, 'D1', 10200)
# (112, 'P12', 'A12', 3, 'D3', 10040)
# (113, 'P13', 'A13', 2, 'D2', 10200)

# %%
print(cursor)

# %%
cursor = conn.execute("select * from Employees where dept_id = 1;")
for row in cursor:
  print(row)
# Out:
# (101, 'P1', 'A1', 1, 'D1', 1000)
# (105, 'P5', 'A5', 1, 'D1', 1200)
# (111, 'P11', 'A11', 1, 'D1', 10200)

# %%
# prompt: using the sqllite3 package, create a database, create a table and add 5 rows of data and select only 3 rows of data from it

import sqlite3

conn = sqlite3.connect('test.db')
conn.execute(''' CREATE TABLE Employees (emp_id INT, emp_name VARCHAR, address VARCHAR, dept_id INT, dept_name VARCHAR, salary INT); ''')
conn.commit()

print("table created")
cursor = conn.execute(""" SELECT * FROM Employees""")
for row in cursor:
  print(row)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (101, 'P1', 'A1', 1, 'D1', 1000); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (102, 'P2', 'A2', 2, 'D2', 10000); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (103, 'P3', 'A3', 3, 'D3', 12000); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (104, 'P4', 'A4', 2, 'D2', 11000); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (105, 'P5', 'A5', 1, 'D1', 1200); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (106, 'P6', 'A6', 3, 'D3', 1300); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (107, 'P7', 'A7', 2, 'D2', 1400); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (108, 'P8', 'A8', 4, 'D4', 12100); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (109, 'P9', 'A9', 4, 'D4', 10030); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (110, 'P10', 'A10', 2, 'D2', 10200); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (111, 'P11', 'A11', 1, 'D1', 10200); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (112, 'P12', 'A12', 3, 'D3', 10040); """)
conn.execute(""" INSERT INTO Employees (emp_id, emp_name, address, dept_id, dept_name, salary) VALUES (113, 'P13', 'A13', 2, 'D2', 10200); """)

conn.commit()
conn = sqlite3.connect('test.db')
cursor = conn.execute("select * from Employees;")
for row in cursor:
  print(row)
cursor = conn.execute("select * from Employees where dept_id = 1;")
for row in cursor:
  print(row)
cursor = conn.execute("select * from Employees limit 3;")
for row in cursor:
  print(row)
